# %%
import pandas as pd

# %%
sales=pd.read_csv('C:/Users/hp/Downloads/Sales.csv',encoding='ISO-8859-1')
sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
sales.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# Delivery Date    object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %%
date_formats=['%d/%m/%Y','%m/%d/%Y','%d-%m-%Y','%m-%d-%Y']

def parse_date(date_str):
    for fmt in date_formats:
        try:
            return pd.to_datetime(date_str,format=fmt)
        except ValueError:
            continue
    return pd.NaT
   
# Apply parsing function to the date column
sales['Order Date']=sales['Order Date'].apply(parse_date)
sales['Delivery Date']=sales['Delivery Date'].apply(parse_date)


# Convert to the desired format
#sales['Order Date']=sales['Order Date'].astype(str)
#sales['Delivery Date']=sales['Delivery Date'].astype(str)

# %%
# Convert to the desired format
sales['Order Date']=sales['Order Date'].dt.strftime('%Y-%m-%d')
sales['Delivery Date']=sales['Delivery Date'].dt.strftime('%Y-%m-%d')

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.fillna('NaT',inplace=True)

# %%
sales
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01           NaT       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-12-01       266019
# 4            366002          2  2016-01-01    2016-12-01       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20           NaT      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
customers=pd.read_csv('C:/Users/hp/Downloads/customers.csv',encoding='ISO-8859-1')
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customers.dtypes
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %%
# Apply parsing function to date column
customers['Birthday']=customers['Birthday'].apply(parse_date)

# Convert to the desired format
customers['Birthday']=customers['Birthday'].dt.strftime('%Y-%m-%d')

# %%
customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customers.fillna('Not Available',inplace=True)

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
exchangerates=pd.read_csv('C:/Users/hp/Downloads/Exchange_Rates.csv',encoding='ISO-8859-1')
exchangerates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchangerates.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
# Apply parsing function to date column
exchangerates['Date']=exchangerates['Date'].apply(parse_date)

# Convert to the desired format
exchangerates['Date']=exchangerates['Date'].dt.strftime('%Y-%m-%d')

# %%
exchangerates.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
products=pd.read_csv('C:/Users/hp/Downloads/products.csv',encoding='ISO-8859-1')
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
products.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
products['Unit Cost USD']=products['Unit Cost USD'].str.replace('[$,]','',regex=True).astype(float)
products['Unit Price USD']=products['Unit Price USD'].str.replace('[$,]','',regex=True).astype(float)

# %%
products.dtypes
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object

# %%
products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
stores=pd.read_csv('C:/Users/hp/Downloads/Stores.csv',encoding='ISO-8859-1')
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
stores.dtypes
# Out:
# StoreKey           int64
# Country           object
# State             object
# Square Meters    float64
# Open Date         object
# dtype: object

# %%
# Apply parsing function to date column
stores['Open Date']=stores['Open Date'].apply(parse_date)

# Convert to the desired format
stores['Open Date']=stores['Open Date'].dt.strftime('%Y-%m-%d')

# %%
stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
stores.fillna(0,inplace=True)

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#      Open Date
# 0   2008-01-01
# 1   2008-12-01
# 2   2012-07-01
# 3   2010-01-01
# ...

# %%
overall=sales

# %%
overall=pd.merge(overall,customers,left_on='CustomerKey',right_on='CustomerKey',how='inner')
overall
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01           NaT       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-12-01       266019
# 4            366002          2  2016-01-01    2016-12-01       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20           NaT      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  \
# 0            10        1304         1           CAD    Male
# ...

# %%
overall=pd.merge(overall,exchangerates,left_on=['Order Date','Currency Code'],right_on=['Date','Currency'],how='inner')
overall
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01           NaT       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-12-01       266019
# 4            366002          2  2016-01-01    2016-12-01       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20           NaT      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# ...

# %%
overall=pd.merge(overall,products,on='ProductKey',how='inner')
overall
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01           NaT       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-12-01       266019
# 4            366002          2  2016-01-01    2016-12-01       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20           NaT      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  ... Exchange  \
# ...

# %%
overall=pd.merge(overall,stores,on=['StoreKey','Country','State'],how='inner')
overall
# Out:
#       Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0           366005          1  2016-01-01           NaT       844003
# 1           367006          1  2016-02-01           NaT       693285
# 2           367010          1  2016-02-01           NaT      1322959
# 3           367010          2  2016-02-01           NaT      1322959
# 4           369007          1  2016-04-01           NaT       571622
# ...            ...        ...         ...           ...          ...
# 5940       2243014          1  2021-02-20           NaT      1453427
# 5941       2243014          2  2021-02-20           NaT      1453427
# 5942       2243014          3  2021-02-20           NaT      1453427
# 5943       2243021          1  2021-02-20           NaT      1783631
# 5944       2243021          2  2021-02-20           NaT      1783631
#
#       StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# 0           33         421         4           EUR    Male  ...
# ...

# %%
overall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5945 entries, 0 to 5944
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Number    5945 non-null   int64
#  1   Line Item       5945 non-null   int64
#  2   Order Date      5945 non-null   object
#  3   Delivery Date   5945 non-null   object
#  4   CustomerKey     5945 non-null   int64
#  5   StoreKey        5945 non-null   int64
#  6   ProductKey      5945 non-null   int64
#  7   Quantity        5945 non-null   int64
#  8   Currency Code   5945 non-null   object
#  9   Gender          5945 non-null   object
#  10  Name            5945 non-null   object
#  11  City            5945 non-null   object
#  12  State Code      5945 non-null   object
#  13  State           5945 non-null   object
#  14  Zip Code        5945 non-null   object
#  15  Country         5945 non-null   object
#  16  Continent       5945 non-null   object
# ...

# %%
# Save the cleaned dataset to a new CSV file
Output_path = "C:/Users/hp/Downloads/Data_Spark.csv"
overall.to_csv(Output_path, index=False)

# %%
pd.read_csv('C:/Users/hp/Downloads/Data_Spark.csv')
# Out:
#       Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0           366005          1  2016-01-01           NaT       844003
# 1           367006          1  2016-02-01           NaT       693285
# 2           367010          1  2016-02-01           NaT      1322959
# 3           367010          2  2016-02-01           NaT      1322959
# 4           369007          1  2016-04-01           NaT       571622
# ...            ...        ...         ...           ...          ...
# 5940       2243014          1  2021-02-20           NaT      1453427
# 5941       2243014          2  2021-02-20           NaT      1453427
# 5942       2243014          3  2021-02-20           NaT      1453427
# 5943       2243021          1  2021-02-20           NaT      1783631
# 5944       2243021          2  2021-02-20           NaT      1783631
#
#       StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# 0           33         421         4           EUR    Male  ...
# ...

# %%
import pymysql
import pandas as pd

# Connect to MySQL
myconnection = pymysql.connect(host='127.0.0.1', user='root', passwd='Dev@n$h!@28') 
myconnection.cursor().execute('create database if not exists Capstone2')

# %%
# Load CSV data
df = pd.read_csv("C:/Users/hp/Downloads/Data_Spark.csv")

col = [i.replace(" ","_") for i in df.columns]
# Replace data types from pandas to MySQL
a = ",".join(f"{i} {j}" for i, j in zip(col, df.dtypes)).replace("float64", "FLOAT").replace("object", "TEXT").replace("int64", "INT")
# Use a valid table name
table_name = "Data_Spark"

# Create the table
myconnection.cursor().execute(f"create table capstone2.{table_name} ({a})")
for i in range(len(df)):
    myconnection.cursor().execute(f"insert into capstone2.Data_Spark values {tuple(df.iloc[i])}")
    myconnection.commit
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[157], line 20
#      18 myconnection.cursor().execute(f"create table capstone2.{table_name} ({a})")
#      19 for i in range(len(df)):
# ---> 20     myconnection.cursor().execute(f"insert into capstone2.Data_Spark values {tuple(df.iloc[i])}")
#      21     myconnection.commit
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# ...
